# %%
import tensorflow as tf

def setup_gpu():
    physical_devices = tf.config.list_physical_devices('GPU')
    if physical_devices:
        try:
            tf.config.experimental.set_memory_growth(physical_devices[0], True)
            print("config augmentation allocation mémoire gpu activée")
        except RuntimeError as e:
            print(e)

setup_gpu()
# Out:
# config augmentation allocation mémoire gpu activée

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sea
import sklearn
import scipy as sc
import nltk as nltk
import statsmodels as statsmodels
import os

# %% [markdown]
# ## Panneau de configuration

# %%
project_path = "C:\\Users\\charl\\Documents\\workspace\\green_ia\\cch\\"
nbr_to_grab = '01'

# %%
train_df = pd.read_csv(project_path + f'data\\cat_train_df_{nbr_to_grab}.csv', sep=';')
test_df = pd.read_csv(project_path + f'data\\cat_test_df_{nbr_to_grab}.csv', sep=';')
valid_df = pd.read_csv(project_path + f'data\\cat_valid_df_{nbr_to_grab}.csv', sep=';')

# %%
train_df.tail(3)
# Out:
#                        product_name          pnns_groups_1  \
# 994482                     Basilico         Fat and sauces
# 994483            Betteraves rouges  Fruits and vegetables
# 994484  Escagaro pâtes alimentaires   Cereals and potatoes
#
#                pnns_groups_2 ecoscore_grade  energy-kcal_100g  energy_100g  \
# 994482  Dressings and sauces              b              46.0        194.0
# 994483            Vegetables              a              43.0        180.0
# 994484               Cereals        unknown             363.0       1519.0
#
#         fat_100g  saturated-fat_100g  carbohydrates_100g  sugars_100g  \
# 994482       1.2                 0.2            6.900000          4.9
# 994483       0.1                 0.0            7.200000          6.7
# 994484       3.0                 0.6           74.400002          5.0
#
#         proteins_100g  salt_100g  sodium_100g        brands_tags  \
# 994482            1.4        1.1         0.44        franz-josef
# 994483            2.3        0.1         0.04                NaN
# 994484           13.9        NaN          NaN  domaine-de-peries
#
#                                           categories_tags  \
# 994482  en:condiments,en:sauces,en:meal-sauces,en:toma...
# 994483  en:plant-based-foods-and-beverages,en:plant-ba...
# 994484  en:plant-based-foods-and-beverages,en:plant-ba...
#
#                main_category_en
# 994482                Groceries
# 994483  fr:Betteraves sous vide
# 994484                   Pastas

# %%
test_df.tail(3)
# Out:
#                   product_name            pnns_groups_1   pnns_groups_2  \
# 116312               Burro Pam           Fat and sauces            Fats
# 116313           Giro d’Italia          Composite foods  One-dish meals
# 116314  Grana Padano, gerieben  Milk and dairy products          Cheese
#
#        ecoscore_grade  energy-kcal_100g  energy_100g  fat_100g  \
# 116312              d             752.0       3146.0      83.0
# 116313        unknown             261.0       1092.0      11.0
# 116314              c             398.0       1654.0      29.0
#
#         saturated-fat_100g  carbohydrates_100g  sugars_100g  proteins_100g  \
# 116312                58.0                 0.7          0.7            0.6
# 116313                 2.1                32.0          6.6            7.4
# 116314                18.0                 0.0          0.0           33.0
#
#         salt_100g  sodium_100g   brands_tags  \
# 116312        NaN          NaN  pam-panorama
# 116313        1.3         0.52          rana
# 116314        1.5         0.60     san-fabio
#
#                                           categories_tags main_category_en
# 116312  en:dairies,en:fats,en:spreads,en:spreadable-fa...          Butters
# 116313  en:meals,en:pasta-dishes,en:stuffed-pastas,en:...       Tortellini
# 116314  en:dairies,en:fermented-foods,en:fermented-mil...     Grana Padano

# %%
valid_df.tail(3)
# Out:
#                                 product_name            pnns_groups_1  \
# 52339                 Chicken Tikka Sandwich          Composite foods
# 52340                  Calsbourg beurre salé           Fat and sauces
# 52341  Grana Padano a scaglie (= en copeaux)  Milk and dairy products
#
#       pnns_groups_2 ecoscore_grade  energy-kcal_100g  energy_100g  fat_100g  \
# 52339    Sandwiches        unknown               NaN          NaN       NaN
# 52340          Fats              d             734.0       3071.0      81.0
# 52341        Cheese              c             398.0       1654.0      29.0
#
#        saturated-fat_100g  carbohydrates_100g  sugars_100g  proteins_100g  \
# 52339                 NaN                 NaN          NaN            NaN
# 52340                54.2                 0.6          0.6            0.6
# 52341                18.0                 0.0          0.0           33.0
#
#        salt_100g  sodium_100g              brands_tags  \
# 52339        NaN          NaN                     coop
# 52340        1.5          0.6       calsbourg,savencia
# 52341        1.5          0.6  auchan,tavola-in-italia
#
#                                          categories_tags main_category_en
# 52339                                      en:sandwiches       Sandwiches
# 52340  en:dairies,en:fats,en:spreads,en:spreadable-fa...   Salted butters
# 52341  en:dairies,en:fermented-foods,en:fermented-mil...    Grated cheese

# %%
X = [
    'product_name',
    'pnns_groups_1',
    'ecoscore_grade',
    'energy-kcal_100g',
    'energy_100g',
    'fat_100g',
    'saturated-fat_100g',
    'carbohydrates_100g',
    'sugars_100g',
    'proteins_100g',
    'salt_100g',
    'sodium_100g',
    'brands_tags',
    'categories_tags',
    'main_category_en'
]

y = ['pnns_groups_2']
