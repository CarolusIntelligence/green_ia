# %%
import pandas as pd
df = pd.read_csv('/home/carolus/Documents/school/green_ia/data/174_data/174_valid_with_predictions.csv')

# %%
df['ecart'] = df['ecoscore_score'] - df['predictions']
moyenne_ecart = df['ecart'].mean()
mediane_ecart = df['ecart'].median()
print(f"moyenne: {moyenne_ecart}")
print(f"median: {mediane_ecart}")
# Out:
# moyenne: -0.6122959395299211
# median: -0.9402332305908203

# %%
def assign_tag(value):
    if 0 <= value < 20:
        return 'e'
    elif 20 <= value < 40:
        return 'd'
    elif 40 <= value < 60:
        return 'c'
    elif 60 <= value < 80:
        return 'b'
    elif 80 <= value <= 100:
        return 'a'
    else:
        return None  # Valeurs hors des plages spécifiées

# Appliquer la fonction à la colonne 'predictions'
df['tags_pred'] = df['predictions'].apply(assign_tag)

# %%
colonnes_a_afficher = ['ecoscore_score', 'predictions', 'ecoscore_tags', 'tags_pred']
df[colonnes_a_afficher].head(60)
# Out:
#     ecoscore_score  predictions ecoscore_tags tags_pred
# 0               42    46.433197             c         c
# 1               46    48.838131             c         c
# 2               71    71.462410             b         b
# 3               79    73.772087             b         b
# 4               79    64.112686             b         b
# 5               72    65.319733             b         b
# 6               72    72.829170             b         b
# 7               64    65.975006             b         b
# 8               43    44.074596             c         c
# 9               22    27.066938             d         d
# 10              63    63.139175             b         b
# 11              76    77.989159             b         b
# 12              72    74.757141             b         b
# 13              58    54.977924             c         c
# 14              67    68.494682             b         b
# 15              39    43.396275             d         c
# 16              58    60.895184             c         b
# 17              62    75.527489             b         b
# 18              64    74.156898             b         b
# 19              24    25.924149             d         d
# 20              72    74.603172             b         b
# 21              50    44.832165             c         c
# 22              22    33.107742             d         d
# 23              67    60.114208             b         b
# 24              90    71.931305             a         b
# 25              75    75.644608             b         b
# 26              78    77.901505             b         b
# 27              53    52.896999             c         c
# 28              58    61.280537             c         b
# 29              48    45.714828             c         c
# 30              79    78.010567             b         b
# 31              44    44.217220             c         c
# 32              88    86.264198             a         a
# 33              42    49.384579             c         c
# 34              68    69.342636             b         b
# 35              18    16.569288             e         e
# 36              47    43.905930             c         c
# 37              67    74.939987             b         b
# 38              67    62.298817             b         b
# 39              63    63.167400             b         b
# 40               5     5.685246             e         e
# 41              45    36.728294             c         d
# 42               0     7.574039             e         e
# 43              33    30.617645             d         d
# 44              62    50.467983             b         c
# 45              35    34.525295             d         d
# 46              72    51.253033             b         c
# 47              67    64.061172             b         b
# 48              77    65.919380             b         b
# 49             100    87.955070             a         a
# 50              35    42.770359             d         c
# 51              79    82.603706             b         a
# 52              60    59.714710             b         c
# 53              79    78.858330             b         b
# 54              75    74.008751             b         b
# 55              75    77.059311             b         b
# 56              49    32.172703             c         d
# 57              67    70.514992             b         b
# 58              35    36.809494             d         d
# 59               0     5.896855             e         e

# %%
def pourcentage_lettres_non_identiques(str1, str2):
    max_len = max(len(str1), len(str2))
    str1 = str1.ljust(max_len)
    str2 = str2.ljust(max_len)
    non_identiques = sum(c1 != c2 for c1, c2 in zip(str1, str2))
    pourcentage = (non_identiques / max_len) * 100
    return pourcentage

df = df[['ecoscore_tags', 'tags_pred']].head(60)
df['pourcentage_non_identiques'] = df.apply(
    lambda row: pourcentage_lettres_non_identiques(row['ecoscore_tags'], row['tags_pred']),
    axis=1
)
lignes_non_identiques = df[df['pourcentage_non_identiques'] > 0]

print("Lignes avec des lettres non identiques :")
print(lignes_non_identiques[['ecoscore_tags', 'tags_pred', 'pourcentage_non_identiques']])
pourcentage_moyen_non_identiques = df['pourcentage_non_identiques'].mean()
print(f"% non identique moyen: {pourcentage_moyen_non_identiques:.2f}%")
# Out:
# Lignes avec des lettres non identiques :
#    ecoscore_tags tags_pred  pourcentage_non_identiques
# 15             d         c                       100.0
# 16             c         b                       100.0
# 24             a         b                       100.0
# 28             c         b                       100.0
# 41             c         d                       100.0
# 44             b         c                       100.0
# 46             b         c                       100.0
# 50             d         c                       100.0
# 51             b         a                       100.0
# 52             b         c                       100.0
# 56             c         d                       100.0
# % non identique moyen: 18.33%
