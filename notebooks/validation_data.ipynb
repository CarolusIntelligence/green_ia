# %%
import pandas as pd
import numpy as np
import json
import os
import warnings
from datetime import datetime 

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_colwidth', None)

warnings.filterwarnings("ignore", category=pd.errors.DtypeWarning)

# %%
chunk_size = 1000
file_id = '00'
project_path = "/home/carolus/Documents/school/green_ia/" 
jsonl_02 = project_path + 'data/' + file_id + '_openfoodfacts_02.jsonl' 

# récupérer la date du jour 
current_date_time = datetime.now()
date_format = "%d/%m/%Y %H:%M:%S.%f"
start_date = current_date_time.strftime("%d/%m/%Y %H:%M:%S.%f")[:-3]
date_code = current_date_time.strftime('%d%m%Y%H%M%S') + f"{current_date_time.microsecond // 1000:03d}"

# %%
def add_logs(logData):
    print(logData)
    #with open(f"{project_path}logs/03_analysis_{date_code}_logs.txt", "a") as logFile:
     #   logFile.write(f'{logData}\n')

# %%
# verifie la validité de la structure du fichier jsonl
with open(jsonl_02, 'r') as file:
    for line in file:
        try:
            json_object = json.loads(line)
        except json.JSONDecodeError as e:
            add_logs(f"ERROR decoding jsonl: {e}")

add_logs(f"jsonl format valid: {jsonl_02}")
# Out:
# jsonl format valid: /home/carolus/Documents/school/green_ia/data/00_openfoodfacts_02.jsonl

# %%
# retourne une liste des pays présents dans le fichier (sans doublons dans l'affichage)
def extract_countries_from_jsonl(file_path):
    countries = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            try:
                record = json.loads(line)
                country = record.get('countries')
                
                if country is not None:
                    countries.append(country)
            except json.JSONDecodeError:
                print(f"WARNING line: {line} in {file_path}")
    
    return countries

def delete_duplicates(liste):
    return list(set(liste))


countries_list = extract_countries_from_jsonl(jsonl_02)
countries_list_no_duplicates = delete_duplicates(countries_list)
print(countries_list_no_duplicates)
# Out:
# ['france, vereinigtes königreich, germany', 'república da irlanda, portugal, itália, alemanha, espanha', 'belgique, france, royaume-uni', 'frança, marrocos', 'belgium, france, poland, portugal, romania, spain', 'argentina, bolivia, chile, colombia, ecuador, paraguay, spain, uruguay, venezuela', 'belgien, france, réunion, germany', 'france, saint-pierre-et-miquelon', 'bulgaria, deutschland', 'lithuania, united kingdom, united states', 'spain, marruecos', 'maldive', 'norsko', 'bulgarie, espagne, switzerland', 'italia, austria', 'australia, austria, bélgica, bulgaria, república checa, france, alemania, líbano, spain, suiza', 'belgique, france, allemagne, pologne, la réunion, switzerland', 'royaume-uni, sénégal', 'bolivia, france, alemania, estados unidos', 'belgique, france, switzerland, world', 'sri lanka, germany', 'francja, niemcy, poland, szwajcaria', 'norway, sweden, denmark', 'france, panama, united states', 'france, spain, belgium', 'deutschland, irland', 'europäische union, germany', 'estados unidos, co', 'dinamarca, finlandia, france, alemania, países bajos, noruega, spain, suecia', 'deutschland, österreich, france', 'france, martinique, spanien, germany', '香港, 中华人民共和国', 'spanyolország, magyarország', 'كندا, iraq', 'argentina, bolivia, chile, colombia, ecuador, paraguay, perú, uruguay, venezuela', 'royaume-uni, luxembourg', 'bugarska, hrvatska, německo', 'deutschland, switzerland, world', 'austria, en, germany', 'france, french-polynesia, new-caledonia', 'germany, east germany', 'deutschland, morocco, france', 'finland, germany, greece, sweden', 'austria, france, ireland, ireland', 'méxico, estados unidos, mexico, world', 'república de china, spain', 'royaume-uni, pologne', 'bulgarien, france, italien, germany', 'belgium, france, pays-bas', 'kroatien, france, slowenien, germany', 'czech republic, greece, czech-republic', 'france, royaume-uni', 'france, germany, spain, australia', 'allemagne, royaume-uni, united states, france', 'france, république de macédoine', 'australie, république tchèque, france, allemagne, hongrie, morocco', 'germania, italia, montenegro, italy', 'australia, china', 'france, italy, italia', 'ranska, espanja, finland', 'turquie, united states, égypte', 'curaçao, caribbean netherlands', '日本, china', 'bh', 'italy, spain, ukraine', 'tasty foods αβγε', 'belgique, france, switzerland, france', 'luxembourg, united states', 'belgique, france, roumanie', 'brasil, brasil', 'serbia, france', 'serbie, croatie', 'belgium, france, sweden, switzerland', 'česko, švýcarsko', 'németország, magyarország, hungary', 'italy, serbia', 'algeria, germany', 'germany, suomi', 'slovacchia', 'bolivia, brasil, panamá, nicaragua, el salvador, guatemala, costa rica, honduras', 'ue', 'czech republic, norway', 'belgium, indonesia', 'belgië, oostenrijk', 'belgique, france, guadeloupe, italie, la réunion, espagne, switzerland, en', 'ukraine, deutschland', 'γαλλία, greece', 'france, germany, luxembourg, switzerland, germany', 'république tchèque, belgique', 'angola, france, united states', 'éthiopie', 'germany', 'belgien, france, niederlande, deutschland', 'isle of man, united kingdom', 'france, alemania, italia, marruecos, rumania, spain, suiza', 'australia, bolivia, colombia, costa rica, república dominicana, el salvador, honduras, paraguay, perú, venezuela', 'afghanistan, france, germany', 'france, hungary, spain, germany', 'czech republic, germany, united kingdom', 'france, schweden, germany', 'hrvatska, irska', 'andorra, belgium, france', 'france, italia, luxemburgo, países bajos, spain', 'spain, poland', 'poland, romania', 'finland, france, italy', 'australia, bélgica, bolivia, dinamarca, finlandia, france, alemania, italia, noruega, polonia, spain, suecia, suiza, tailandia', 'australia, new zealand, singapore, germany', 'argentina, chile, perú', 'nederlân', 'franța, republica moldova, românia', 'българия, албания', 'france, espagne, italie, pologne, roumanie', 'aruba, bolivia, canadá, chile, colombia, cuba, república dominicana ...
