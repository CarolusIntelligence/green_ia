# %%
#!pip install pandas

# %%
#pip list

# %%
import pandas as pd

# %%
# df = pd.read_json('export.json')
# df
# #df= df.transpose()
# #df

# %%
# import requests
# import json

# # Liste de codes de produits (remplacez-les par les codes réels que vous souhaitez interroger)
# product_codes = [
#     "7622210449283",
#     "1234567890123",
#     "9876543210987",
#     # Ajoutez ici les codes des 27 produits restants
#     "1111111111111",
#     "2222222222222",
#     "3333333333333",
#     "4444444444444",
#     "5555555555555",
#     "6666666666666",
#     "7777777777777",
#     "8888888888888",
#     "9999999999999",
#     "1010101010101",
#     "2020202020202",
#     "3030303030303",
#     "4040404040404",
#     "5050505050505",
#     "6060606060606",
#     "7070707070707",
#     "8080808080808",
#     "9090909090909",
#     "1212121212121",
#     "1313131313131",
#     "1414141414141",
#     "1515151515151",
#     "1616161616161",
# ]

# # Liste pour stocker les informations de chaque produit
# products_info = []

# # Itérer sur les codes de produits et effectuer une requête pour chaque produit
# for product_code in product_codes:
#     # URL de l'API Open Food Facts pour un produit spécifique
#     api_url = f"https://world.openfoodfacts.org/api/v0/product/{product_code}.json"

#     # Effectuer une requête GET à l'API pour obtenir les données d'un produit
#     response = requests.get(api_url)

#     # Vérifier si la requête a réussi (code de statut 200)
#     if response.status_code == 200:
#         # Récupérer les données JSON de la réponse
#         product_data = response.json()

#         # Ajouter les informations du produit à la liste
#         product_info = {
#             'id': product_data.get('_id', ''),
#             'code': product_data.get('code', ''),
#             'product_name': product_data.get('product_name', ''),
#             'brands': product_data.get('brands', ''),
#             'categories': product_data.get('categories', ''),
#         }

#         # Ajouter d'autres informations disponibles
#         for key in product_data.keys():
#             if key not in ['_id', 'code', 'product_name', 'brands', 'categories']:
#                 product_info[key] = product_data.get(key, '')

#         products_info.append(product_info)
#     else:
#         print(f"La requête a échoué avec le code de statut {response.status_code} pour le produit {product_code}")

# # Sauvegarder les informations des produits dans un fichier JSON
# with open('products_info.json', 'w') as json_file:
#     json.dump(products_info, json_file, indent=2)

# %%
# import requests
# import json

# # Liste de codes de produits (remplacez-les par les codes réels que vous souhaitez interroger)
# product_codes = [
#     "7622210449283",
#     "1234567890123",
#     "9876543210987",
#     # Ajoutez ici les codes des 27 produits restants
#     "1111111111111",
#     "2222222222222",
#     "3333333333333",
#     "4444444444444",
#     "5555555555555",
#     "6666666666666",
#     "7777777777777",
#     "8888888888888",
#     "9999999999999",
#     "1010101010101",
#     "2020202020202",
#     "3030303030303",
#     "4040404040404",
#     "5050505050505",
#     "6060606060606",
#     "7070707070707",
#     "8080808080808",
#     "9090909090909",
#     "1212121212121",
#     "1313131313131",
#     "1414141414141",
#     "1515151515151",
#     "1616161616161",
# ]

# # Liste pour stocker les informations de chaque produit
# products_info = []

# # Itérer sur les codes de produits et effectuer une requête pour chaque produit
# for product_code in product_codes:
#     # URL de l'API Open Food Facts pour un produit spécifique
#     api_url = f"https://world.openfoodfacts.org/api/v0/product/{product_code}.json"

#     # Effectuer une requête GET à l'API pour obtenir les données d'un produit
#     response = requests.get(api_url)

#     # Vérifier si la requête a réussi (code de statut 200)
#     if response.status_code == 200:
#         # Récupérer les données JSON de la réponse
#         product_data = response.json()

#         # Ajouter les informations du produit à la liste
#         product_info = {
#             'id': product_data.get('_id', ''),
#             'code': product_data.get('code', ''),
#             'product_name': product_data.get('product_name', ''),
#             'brands': product_data.get('brands', ''),
#             'categories': product_data.get('categories', ''),
#         }

#         # Ajouter d'autres informations disponibles
#         for key in product_data.keys():
#             if key not in ['_id', 'code', 'product_name', 'brands', 'categories']:
#                 product_info[key] = product_data.get(key, '')

#         products_info.append(product_info)
#     else:
#         print(f"La requête a échoué avec le code de statut {response.status_code} pour le produit {product_code}")

# # Sauvegarder les informations des produits dans un fichier JSON
# with open('products_info.json', 'w') as json_file:
#     json.dump(products_info, json_file, indent=2)

# # Afficher les informations de chaque produit
# for product_info in products_info:
#     print("\nInformations du produit:")
#     for key, value in product_info.items():
#         print(f"{key}: {value}")

# %%
# import requests
# import json

# # Liste de codes de produits (remplacez-les par les codes réels que vous souhaitez interroger)
# product_codes = [
#     "7622210449283",
#     "1234567890123",
#     "9876543210987",
#     # Ajoutez ici les codes des 27 produits restants
#     "1111111111111",
#     "2222222222222",
#     "3333333333333",
#     "4444444444444",
#     "5555555555555",
#     "6666666666666",
#     "7777777777777",
#     "8888888888888",
#     "9999999999999",
#     "1010101010101",
#     "2020202020202",
#     "3030303030303",
#     "4040404040404",
#     "5050505050505",
#     "6060606060606",
#     "7070707070707",
#     "8080808080808",
#     "9090909090909",
#     "1212121212121",
#     "1313131313131",
#     "1414141414141",
#     "1515151515151",
#     "1616161616161",
# ]

# # Dossier pour stocker les fichiers JSON
# output_folder = 'products_json/'

# # Créer le dossier s'il n'existe pas
# import os
# os.makedirs(output_folder, exist_ok=True)

# # Itérer sur les codes de produits et effectuer une requête pour chaque produit
# for i, product_code in enumerate(product_codes, 1):
#     # URL de l'API Open Food Facts pour un produit spécifique
#     api_url = f"https://world.openfoodfacts.org/api/v0/product/{product_code}.json"

#     # Effectuer une requête GET à l'API pour obtenir les données d'un produit
#     response = requests.get(api_url)

#     # Vérifier si la requête a réussi (code de statut 200)
#     if response.status_code == 200:
#         # Récupérer les données JSON de la réponse
#         product_data = response.json()

#         # Sauvegarder les informations du produit dans un fichier JSON spécifique
#         json_filename = f'{output_folder}product_info_{i}.json'
#         with open(json_filename, 'w') as json_file:
#             json.dump(product_data, json_file, indent=2)
#     else:
#         print(f"La requête a échoué avec le code de statut {response.status_code} pour le produit {product_code}")

# %%
# import os
# import pandas as pd
# import json

# # Dossier où sont stockés les fichiers JSON
# input_folder = 'products_json/'

# # Liste pour stocker les DataFrames de chaque fichier JSON
# dataframes = []

# # Itérer sur les fichiers JSON dans le dossier
# for filename in os.listdir(input_folder):
#     if filename.endswith(".json"):
#         file_path = os.path.join(input_folder, filename)

#         # Lire le fichier JSON dans un DataFrame
#         df = pd.read_json(file_path, orient='index')
#         dataframes.append(df)

# # Concaténer tous les DataFrames en un seul
# result_df = pd.concat(dataframes, axis=1).T
# result_df
# # Afficher le DataFrame
# #print(result_df)
# #result_df.to_csv('openfoodfact.csv')

# %%
# #load data
# with open('export_json.json', 'r') as f:
#     data = json.load(f)

# %%
# Nested_values = ['product','ecoscore_data','transportation_values', 'values', 'packaging','threatened_species','agribalyse', 'grades',
#                  'previous_data','scores','_keywords','additives_debug_tags','additives_old_tags','additives_prev_original_tags','data_sources_tags','debug_param_sorted_langs',
#               'packagings','nutrition']
# skip_values = ['_keywords','additives_debug_tags','additives_old_tags','additives_prev_original_tags','data_sources_tags','debug_param_sorted_langs',
#               'packagings','nutrition']
# flattened_data = {}
# for idx,value in enumerate(data):
#     #print(idx)
#     flattened_data[idx] = {}
#     for prop_idx, prop_value in  value.items():

#         if prop_idx in Nested_values:
#             if prop_idx in skip_values:
#                 pass
#             else:
#                 # loop through each nested property
#                 if prop_value is not None:
#                     if isinstance(prop_value, dict):
#                         for nested_idx, nested_value in prop_value.items():
#                             flattened_data[idx][prop_idx+'_'+nested_idx] = prop_value


#         else:
#             flattened_data[idx][prop_idx] = prop_value

# %%
#flattened_data

# %%
# import pandas as pd
# df = pd.DataFrame.from_dict(flattened_data, orient = 'index')
# df
# #df.to_csv('openfood.csv')

# %%
#pip install chardet

# %%
# import chardet

# # Detect file encoding
# with open("en.openfoodfacts.org.products.csv", 'rb') as rawdata:
#     result = chardet.detect(rawdata.read(10000))

# # Use the detected encoding when reading the file
# with open("en.openfoodfacts.org.products.csv", 'r', encoding=result['encoding']) as temp_f:
#     col_count = [len(l.split(",")) for l in temp_f.readlines()]

# # Generate column names
# column_names = [i for i in range(0, max(col_count))]

# %%
df = pd.read_csv("C:/Git/Collecte-datas/en.openfoodfacts.org.products.csv", encoding='utf-8', sep='\t', names=['Colonne1', 'Colonne2','Colonne3', 'Colonne4'])
# Out:
# C:\Users\bamba\AppData\Local\Temp\ipykernel_2100\2736053591.py:1: DtypeWarning: Columns (0,3,5,9,10,12,13,14,15,21,22,23,24,25,29,30,31,32,33,34,35,42,43,44,45,46,48,49,50,51,54,56,65,66,69,70,72,74,75,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128,129,130,131,132,133,134,135,136,137,138,139,140,141,142,143,144,145,146,147,148,149,150,151,152,153,154,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,172,173,174,175,176,177,178,179,180,181,182,183,184,185,186,187,188,189,190,191,192,193,194,195,196,197,198,199,200,201,202,203) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/Git/Collecte-datas/en.openfoodfacts.org.products.csv", encoding='utf-8', sep='\t', names=['Colonne1', 'Colonne2','Colonne3', 'Colonne4'])

# %%
# import requests
# import pandas as pd

# def get_product_info(code):
#     url = f"https://world.openfoodfacts.org/api/v0/product/{code}.json"
#     response = requests.get(url)

#     if response.status_code == 200:
#         data = response.json()

#         if 'product' in data:
#             product_data = data['product']
#             return product_data
#         else:
#             print("Aucune information sur le produit n'a été trouvée.")
#     else:
#         print(f"La requête a échoué avec le code d'état {response.status_code}.")

# # Remplacez cela par le code-barres du produit que vous recherchez
# code = "1234567890123"
# product_info = get_product_info(code)

# if product_info:
#     # Créez un DataFrame Pandas à partir du dictionnaire complet du produit
#     df = pd.DataFrame.from_dict(product_info, orient='index').T

#     # Affichez le DataFrame
#     print(df)

# %%
import pandas as pd
import requests
from io import BytesIO
import gzip

# Lien vers le fichier CSV compressé
url = "https://static.openfoodfacts.org/data/en.openfoodfacts.org.products.csv.gz"

# Télécharger le fichier
response = requests.get(url)

# Vérifier si la requête a réussi
if response.status_code == 200:
    # Décompresser le fichier
    with gzip.GzipFile(fileobj=BytesIO(response.content), mode='rb') as file:
        # Charger le fichier CSV dans un DataFrame Pandas
        df = pd.read_csv(file, sep='\t', encoding='utf-8')

        # Afficher les premières lignes du DataFrame
        print(df.head())
else:
    print(f"La requête a échoué avec le code d'état {response.status_code}.")
# Out:
# C:\Users\bamba\AppData\Local\Temp\ipykernel_21808\1441615606.py:17: DtypeWarning: Columns (0,9,10,12,13,14,15,21,22,23,24,25,29,30,31,32,33,34,35,42,44,45,46,49,50,51,54,65,70,148) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep='\t', encoding='utf-8')
#                      code                                                url  \
# 0       00000000000000225  http://world-en.openfoodfacts.org/product/0000...
# 1  0000000000000207025004  http://world-en.openfoodfacts.org/product/0000...
# 2    00000000000003429145  http://world-en.openfoodfacts.org/product/0000...
# 3    00000000000026772226  http://world-en.openfoodfacts.org/product/0000...
# 4           0000000000017  http://world-en.openfoodfacts.org/product/0000...
#
#           creator   created_t      created_datetime  last_modified_t  \
# 0  nutrinet-sante  1623855208  2021-06-16T14:53:28Z       1692101569
# ...

# %%
df
# Out:
#                            code  \
# 0             00000000000000225
# 1        0000000000000207025004
# 2          00000000000003429145
# 3          00000000000026772226
# 4                 0000000000017
# ...                         ...
# 3036058           9999999990397
# 3036059              9999999999
# 3036060             99999999999
# 3036061            999999999999
# 3036062           9999999999994
#
#                                                        url  \
# 0        http://world-en.openfoodfacts.org/product/0000...
# 1        http://world-en.openfoodfacts.org/product/0000...
# 2        http://world-en.openfoodfacts.org/product/0000...
# 3        http://world-en.openfoodfacts.org/product/0000...
# 4        http://world-en.openfoodfacts.org/product/0000...
# ...                                                    ...
# 3036058  http://world-en.openfoodfacts.org/product/9999...
# 3036059  http://world-en.openfoodfacts.org/product/9999...
# ...

# %%
#p= df.info(max_cols=204)
#print(p)
p= df.info(verbose=True)
#p
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3036063 entries, 0 to 3036062
# Data columns (total 204 columns):
#  #    Column                                                 Dtype
# ---   ------                                                 -----
#  0    code                                                   object
#  1    url                                                    object
#  2    creator                                                object
#  3    created_t                                              int64
#  4    created_datetime                                       object
#  5    last_modified_t                                        int64
#  6    last_modified_datetime                                 object
#  7    last_modified_by                                       object
#  8    product_name                                           object
#  9    abbreviated_product_name                               object
# ...

# %%
#data =df.dropna(axis=1)

# %%
df.describe()
# Out:
#           created_t  last_modified_t  allergens_en  serving_quantity  \
# count  3.036063e+06     3.036063e+06           0.0      6.258700e+05
# mean   1.596315e+09     1.647732e+09           NaN      1.953052e+28
# std    6.652192e+07     4.512133e+07           NaN      1.545097e+31
# min    1.328021e+09     1.353582e+09           NaN      0.000000e+00
# 25%    1.551008e+09     1.617032e+09           NaN      2.800000e+01
# 50%    1.606083e+09     1.661528e+09           NaN      5.700000e+01
# 75%    1.650907e+09     1.682858e+09           NaN      1.210000e+02
# max    1.703655e+09     1.703655e+09           NaN      1.222357e+34
#
#           nova_group  ecoscore_score  product_quantity  unique_scans_n  \
# count  832133.000000   749825.000000      8.841840e+05   858817.000000
# mean        3.338774       48.357301      1.336626e+05        2.399249
# std         1.044864       25.327583      9.381618e+07        6.838993
# ...

# %%
numeric_columns = ['code','url','product_name','created_t', 'last_modified_t','sugars_100g','salt_100g','sodium_100g', 'saturated-fat_100g', 'allergens_en', 'serving_quantity', 'nova_group', 'ecoscore_score','product_quantity', 'unique_scans_n','completeness','glycemic-index_100g','creator','countries_en','nutriscore_grade','nutriscore_score',
                   'sugars_100g','saturated-fat_100g','main_category_en']

# %%
extract_data = df[numeric_columns]

# %%
extract_data
# Out:
#                            code  \
# 0             00000000000000225
# 1        0000000000000207025004
# 2          00000000000003429145
# 3          00000000000026772226
# 4                 0000000000017
# ...                         ...
# 3036058           9999999990397
# 3036059              9999999999
# 3036060             99999999999
# 3036061            999999999999
# 3036062           9999999999994
#
#                                                        url  \
# 0        http://world-en.openfoodfacts.org/product/0000...
# 1        http://world-en.openfoodfacts.org/product/0000...
# 2        http://world-en.openfoodfacts.org/product/0000...
# 3        http://world-en.openfoodfacts.org/product/0000...
# 4        http://world-en.openfoodfacts.org/product/0000...
# ...                                                    ...
# 3036058  http://world-en.openfoodfacts.org/product/9999...
# 3036059  http://world-en.openfoodfacts.org/product/9999...
# ...

# %%
extract_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3036063 entries, 0 to 3036062
# Data columns (total 24 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   code                 object
#  1   url                  object
#  2   product_name         object
#  3   created_t            int64
#  4   last_modified_t      int64
#  5   sugars_100g          float64
#  6   salt_100g            float64
#  7   sodium_100g          float64
#  8   saturated-fat_100g   float64
#  9   allergens_en         float64
#  10  serving_quantity     float64
#  11  nova_group           float64
#  12  ecoscore_score       float64
#  13  product_quantity     float64
#  14  unique_scans_n       float64
#  15  completeness         float64
#  16  glycemic-index_100g  float64
#  17  creator              object
#  18  countries_en         object
#  19  nutriscore_grade     object
#  20  nutriscore_score     object
#  21  sugars_100g          float64
# ...

# %%
extract_data.describe()
# Out:
#           created_t  last_modified_t   sugars_100g     salt_100g  \
# count  3.036063e+06     3.036063e+06  2.288441e+06  2.060138e+06
# mean   1.596315e+09     1.647732e+09  1.437826e+01  2.390562e+02
# std    6.652192e+07     4.512133e+07  1.443216e+03  1.907371e+05
# min    1.328021e+09     1.353582e+09 -1.700000e+01  0.000000e+00
# 25%    1.551008e+09     1.617032e+09  5.600000e-01  1.000000e-01
# 50%    1.606083e+09     1.661528e+09  3.570000e+00  6.000000e-01
# 75%    1.650907e+09     1.682858e+09  1.700000e+01  1.400000e+00
# max    1.703655e+09     1.703655e+09  2.050828e+06  2.261739e+08
#
#         sodium_100g  saturated-fat_100g  allergens_en  serving_quantity  \
# count  2.060136e+06        2.262343e+06           0.0      6.258700e+05
# mean   9.562257e+01        3.363816e+03           NaN      1.953052e+28
# std    7.629489e+04        4.998980e+06           NaN      1.545097e+31
# min    0.000000e+00        0.000000e+00           NaN      0.000000e+00
# ...

# %%
missing_percent = (extract_data.isnull().sum() / len(extract_data)) * 100

# %%
missing_percent
# Out:
# code                     0.000000
# url                      0.000000
# product_name             4.591637
# created_t                0.000000
# last_modified_t          0.000000
# sugars_100g             24.624720
# salt_100g               32.144425
# sodium_100g             32.144491
# saturated-fat_100g      25.484320
# allergens_en           100.000000
# serving_quantity        79.385474
# nova_group              72.591708
# ecoscore_score          75.302719
# product_quantity        70.877284
# unique_scans_n          71.712807
# completeness             0.000099
# glycemic-index_100g     99.999769
# creator                  0.000132
# countries_en             0.553875
# nutriscore_grade        37.127556
# nutriscore_score        66.070928
# sugars_100g             24.624720
# saturated-fat_100g      25.484320
# main_category_en        55.503987
# dtype: float64

# %%
#missing_percent = (train.isnull().sum() / len(train)) * 100
threshold = 70
columns_to_drop = missing_percent[missing_percent > threshold].index.tolist()
train = extract_data.drop(columns=columns_to_drop)
train
# Out:
#                            code  \
# 0             00000000000000225
# 1        0000000000000207025004
# 2          00000000000003429145
# 3          00000000000026772226
# 4                 0000000000017
# ...                         ...
# 3036058           9999999990397
# 3036059              9999999999
# 3036060             99999999999
# 3036061            999999999999
# 3036062           9999999999994
#
#                                                        url  \
# 0        http://world-en.openfoodfacts.org/product/0000...
# 1        http://world-en.openfoodfacts.org/product/0000...
# 2        http://world-en.openfoodfacts.org/product/0000...
# 3        http://world-en.openfoodfacts.org/product/0000...
# 4        http://world-en.openfoodfacts.org/product/0000...
# ...                                                    ...
# 3036058  http://world-en.openfoodfacts.org/product/9999...
# 3036059  http://world-en.openfoodfacts.org/product/9999...
# ...

# %%
remaining_missing = extract_data.isnull().sum()
remaining_missing = remaining_missing[remaining_missing > 0]
remaining_missing.sort_values(inplace=True)
remaining_missing.plot.bar()
# Out:
# <Axes: >

# %%
#pip install matplotlib
#!pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# ... (votre code précédent)

null_columns = extract_data.isnull().sum().sort_values(ascending=False)
sns.set(style="darkgrid")
plt.figure(figsize=(25, 4))
sns.barplot(x=null_columns.index, y=null_columns)
plt.show()
